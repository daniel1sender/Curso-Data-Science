# %% [markdown]
# # Métodos de Strings

# %%
import numpy as np
import pandas as pd

# %%
arquivo = "c:\\Users\\dan\\Documents\\Curso Data Science\\Datasets\\sanduiches.txt"
vendas = pd.read_table(arquivo)
vendas.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# como utilizamos o método de string normalmente no Python puro
'data science'.upper()
# Out:
# 'DATA SCIENCE'

# %% [markdown]
# # Os métodos de strings no Pandas são acessados via .str

# %%
vendas.item_name.str.upper().head()
# Out:
# 0             CHIPS AND FRESH TOMATO SALSA
# 1                                     IZZE
# 2                         NANTUCKET NECTAR
# 3    CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                             CHICKEN BOWL
# Name: item_name, dtype: object

# %%
vendas.item_name.str.contains('Chicken').head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: item_name, dtype: bool

# %%
#Aplicando a série ao dataframe de forma direta
vendas[vendas.item_name.str.contains('Chicken')].head(20)
# Out:
#     order_id  quantity             item_name  \
# 4          2         2          Chicken Bowl
# 5          3         1          Chicken Bowl
# 11         6         1  Chicken Crispy Tacos
# 12         6         1    Chicken Soft Tacos
# 13         7         1          Chicken Bowl
# 16         8         1       Chicken Burrito
# 17         9         1       Chicken Burrito
# 19        10         1          Chicken Bowl
# 23        12         1       Chicken Burrito
# 26        13         1          Chicken Bowl
# 29        15         1       Chicken Burrito
# 35        18         1    Chicken Soft Tacos
# 36        18         1    Chicken Soft Tacos
# 42        20         1          Chicken Bowl
# 44        20         1    Chicken Salad Bowl
# 45        21         1       Chicken Burrito
# 52        24         1       Chicken Burrito
# 63        28         1       Chicken Burrito
# 68        30         1       Chicken Burrito
# 73        33         1       Chicken Burrito
#
# ...

# %%
vendas.item_name.str.contains('Tomato').head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: item_name, dtype: bool

# %%
vendas[vendas.item_name.str.contains('Tomato')].head(20)
# Out:
#      order_id  quantity                          item_name choice_description  \
# 0           1         1       Chips and Fresh Tomato Salsa                NaN
# 25         13         1       Chips and Fresh Tomato Salsa                NaN
# 55         25         1       Chips and Fresh Tomato Salsa                NaN
# 89         39         1       Chips and Fresh Tomato Salsa                NaN
# 183        82         1       Chips and Fresh Tomato Salsa                NaN
# 194        86         1       Chips and Fresh Tomato Salsa                NaN
# 240       104         1       Chips and Fresh Tomato Salsa                NaN
# 265       115         1       Chips and Fresh Tomato Salsa                NaN
# 267       116         1       Chips and Fresh Tomato Salsa                NaN
# 302       131         1       Chips and Fresh Tomato Salsa                NaN
# 326       142         1       Chips and Fresh Tomato Salsa                NaN
# ...

# %% [markdown]
# Vamos retirar os colchetes da lista de ingredientes

# %%
a = vendas.choice_description.str.replace('[', '').str.replace(']', '').head(10)

# %%
vendas['choice_description'] = pd.Series(a)

# %%
vendas.head(20)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...
