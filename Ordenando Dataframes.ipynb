# %%
import numpy as np
import pandas as pd

# %%
colunas_filmes = ['star_rating', 'title', 'content_rating', 'genre', 'duration', 'actors_list']

file ="c:\\Users\\dan\\Documents\\Curso Data Science\\Datasets\\movies.csv"
filmes = pd.read_csv(file, header=0, names=colunas_filmes)
filmes.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
type(filmes)
# Out:
# pandas.core.frame.DataFrame

# %%
filmes.title.sort_values().head(120)
# Out:
# 542         (500) Days of Summer
# 5                   12 Angry Men
# 201             12 Years a Slave
# 698                    127 Hours
# 110        2001: A Space Odyssey
#                  ...
# 651                Blood Simple.
# 725                         Blow
# 673                      Blow-Up
# 456    Blue Is the Warmest Color
# 972               Blue Valentine
# Name: title, Length: 120, dtype: object

# %%
A = filmes.title.sort_values()
type(A)
# Out:
# pandas.core.series.Series

# %%
A.tail()
# Out:
# 955    Zero Dark Thirty
# 677              Zodiac
# 615          Zombieland
# 526                Zulu
# 864               [Rec]
# Name: title, dtype: object

# %%
filmes.title.sort_values(ascending=False).head(10)
# Out:
# 864                 [Rec]
# 526                  Zulu
# 615            Zombieland
# 677                Zodiac
# 955      Zero Dark Thirty
# 535                 Zelig
# 280    Young Frankenstein
# 96                Yojimbo
# 235               Yip Man
# 403            Ying xiong
# Name: title, dtype: object

# %%
filmes.sort_values('title').head()
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 201          8.1       12 Years a Slave              R  Biography       134
# 698          7.6              127 Hours              R  Adventure        94
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
#
#                                            actors_list
# 542  [u'Zooey Deschanel', u'Joseph Gordon-Levitt', ...
# 5    [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 201  [u'Chiwetel Ejiofor', u'Michael Kenneth Willia...
# 698  [u'James Franco', u'Amber Tamblyn', u'Kate Mara']
# 110  [u'Keir Dullea', u'Gary Lockwood', u'William S...

# %%
filmes.sort_values('title', ascending=False).head()
# Out:
#      star_rating             title content_rating   genre  duration  \
# 864          7.5             [Rec]              R  Horror        78
# 526          7.8              Zulu        UNRATED   Drama       138
# 615          7.7        Zombieland              R  Comedy        88
# 677          7.7            Zodiac              R   Crime       157
# 955          7.4  Zero Dark Thirty              R   Drama       157
#
#                                            actors_list
# 864  [u'Manuela Velasco', u'Ferran Terraza', u'Jorg...
# 526  [u'Stanley Baker', u'Jack Hawkins', u'Ulla Jac...
# 615  [u'Jesse Eisenberg', u'Emma Stone', u'Woody Ha...
# 677  [u'Jake Gyllenhaal', u'Robert Downey Jr.', u'M...
# 955  [u'Jessica Chastain', u'Joel Edgerton', u'Chri...

# %%
filmes.sort_values(['genre', 'duration']).head(20)
# Out:
#      star_rating                         title content_rating   genre  \
# 533          7.8                  Run Lola Run              R  Action
# 633          7.7                  The Warriors              R  Action
# 455          7.9                         Taken          PG-13  Action
# 685          7.7                   First Blood              R  Action
# 744          7.6   Mad Max 2: The Road Warrior              R  Action
# 619          7.7              Forbidden Planet         PASSED  Action
# 276          8.1          A Fistful of Dollars              R  Action
# 403          7.9                    Ying xiong          PG-13  Action
# 552          7.8                Kung Fu Hustle              R  Action
# 740          7.6          The Raid: Redemption              R  Action
# 327          8.0  The Adventures of Robin Hood             PG  Action
# 515          7.8                   Dirty Harry              R  Action
# ...

# %% [markdown]
# # Filtrando dataframes

# %%
boleanos = []

for length in filmes.duration:
    if length >= 200:
        boleanos.append(True)
    else:
        boleanos.append(False)

# %%
boleanos[:20]
# Out:
# [False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False]

# %%
len(boleanos)
# Out:
# 979

# %%
duração = pd.Series(boleanos)
duração.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
#Podemos usar a notação de colchetes para indexar ou para aplicar filtros de series boleanas
print(filmes['title'][:10])
# Out:
# 0                         The Shawshank Redemption
# 1                                    The Godfather
# 2                           The Godfather: Part II
# 3                                  The Dark Knight
# 4                                     Pulp Fiction
# 5                                     12 Angry Men
# 6                   The Good, the Bad and the Ugly
# 7    The Lord of the Rings: The Return of the King
# 8                                 Schindler's List
# 9                                       Fight Club
# Name: title, dtype: object

# %%
filmes[duraçaõ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f2b14a313ef0> in <module>
# ----> 1 filmes[duraçaõ]
#
# NameError: name 'duraçaõ' is not defined

# %%
#pego a série boleana e aplico no no dataframe ele só trará os campos onde forem true, ou seja, campos maiores que 200
filmes[duração]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
filmes[duração][['title', 'star_rating']]
# Out:
#                                              title  star_rating
# 2                           The Godfather: Part II          9.1
# 7    The Lord of the Rings: The Return of the King          8.9
# 17                                   Seven Samurai          8.7
# 78                     Once Upon a Time in America          8.4
# 85                              Lawrence of Arabia          8.4
# 142              Lagaan: Once Upon a Time in India          8.3
# 157                             Gone with the Wind          8.2
# 204                                        Ben-Hur          8.1
# 445                           The Ten Commandments          7.9
# 476                                         Hamlet          7.8
# 630                                      Malcolm X          7.7
# 767                It's a Mad, Mad, Mad, Mad World          7.6

# %% [markdown]
# # podemos simplificar o filtro da forma abaixo ou com List Comprehension

# %%
#forma simplificada

A = filmes.duration >= 180
A.head(20)
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# Name: duration, dtype: bool

# %%
filmes[A]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 8            8.9                               Schindler's List
# 17           8.7                                  Seven Samurai
# 40           8.5                                 The Green Mile
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 89           8.4                                         Swades
# 93           8.4                    Dilwale Dulhania Le Jayenge
# 109          8.3                                 Dil Chahta Hai
# 132          8.3                          Judgment at Nuremberg
# 142          8.3              Lagaan: Once Upon a Time in India
# 143          8.2                        The Wolf of Wall Street
# 157          8.2                             Gone with the Wind
# ...

# %%
#Escrevendo por List Comprehension
filmes[filmes.duration >= 180].head()
# Out:
#     star_rating                                          title content_rating  \
# 2           9.1                         The Godfather: Part II              R
# 7           8.9  The Lord of the Rings: The Return of the King          PG-13
# 8           8.9                               Schindler's List              R
# 17          8.7                                  Seven Samurai        UNRATED
# 40          8.5                                 The Green Mile              R
#
#         genre  duration                                        actors_list
# 2       Crime       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7   Adventure       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 8   Biography       195  [u'Liam Neeson', u'Ralph Fiennes', u'Ben Kings...
# 17      Drama       207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 40      Crime       189  [u'Tom Hanks', u'Michael Clarke Duncan', u'Dav...

# %%
genero_maior_200 = filmes[filmes.duration >= 200].genre

# %%
genero_maior_200
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %%
type(genero_maior_200)
# Out:
# pandas.core.series.Series

# %%
genero_maior_200 = filmes[filmes.duration >= 200]['genre']

# %%
genero_maior_200
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %%
#Porém, por boa prática, utilizamos sempre o método LOC que nada mais é do que definir uam condição e filtrar por labels

filmes.loc[filmes.duration >= 200, 'genre']
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object
